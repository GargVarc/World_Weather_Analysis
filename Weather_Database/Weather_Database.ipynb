# %%
# Import the dependencies.
import pandas as pd
# import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 779

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | padang
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | orlik
# Processing Record 6 of Set 1 | yoichi
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | karaton
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | balykshi
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | namatanai
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | la libertad
# Processing Record 18 of Set 1 | qaqortoq
# Processing Record 19 of Set 1 | muisne
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | clyde river
# Processing Record 23 of Set 1 | nanortalik
# Processing Record 24 of Set 1 | bambanglipuro
# Processing Record 25 of Set 1 | surgut
# Processing Record 26 of Set 1 | dzhebariki-khaya
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | upata
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | paraiso
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | petropavlovka
# Processing Record 34 of Set 1 | atbasar
# Processing Record 35 of Set 1 | lac du bonnet
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | tignere
# Processing Record 40 of Set 1 | inhambane
# Processing Record 41 of Set 1 | xai-xai
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | thap than
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | rawson
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | tanout
# Processing Record 48 of Set 1 | lagoa
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | egvekinot
# Processing Record 2 of Set 2 | ixtapa
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | ouango
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | erzin
# Processing Record 7 of Set 2 | dabakala
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | lavrentiya
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | kendari
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | constantine
# Processing Record 16 of Set 2 | pangai
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | policoro
# Processing Record 20 of Set 2 | husavik
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | itacarambi
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | oranjestad
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | saint george
# Processing Record 29 of Set 2 | williamsburg
# Processing Record 30 of Set 2 | touros
# Processing Record 31 of Set 2 | jiaocheng
# Processing Record 32 of Set 2 | chara
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | ogulin
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | itarema
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | alofi
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | sistranda
# Processing Record 44 of Set 2 | nabire
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | cabadiangan
# Processing Record 48 of Set 2 | kahului
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | kathmandu
# Processing Record 1 of Set 3 | lukulu
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | nantucket
# Processing Record 4 of Set 3 | broome
# Processing Record 5 of Set 3 | lazaro cardenas
# Processing Record 6 of Set 3 | sabang
# Processing Record 7 of Set 3 | omboue
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | sangerhausen
# Processing Record 10 of Set 3 | lorengau
# Processing Record 11 of Set 3 | mayumba
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | sur
# Processing Record 16 of Set 3 | puerto escondido
# Processing Record 17 of Set 3 | porto santo
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | adrar
# Processing Record 20 of Set 3 | nome
# Processing Record 21 of Set 3 | dhidhdhoo
# Processing Record 22 of Set 3 | tabuk
# Processing Record 23 of Set 3 | tilichiki
# Processing Record 24 of Set 3 | burns lake
# Processing Record 25 of Set 3 | goshogawara
# Processing Record 26 of Set 3 | paka
# Processing Record 27 of Set 3 | hasaki
# Processing Record 28 of Set 3 | camargo
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | taltal
# Processing Record 33 of Set 3 | goderich
# Processing Record 34 of Set 3 | hiriyur
# Processing Record 35 of Set 3 | lahaina
# Processing Record 36 of Set 3 | zharkent
# Processing Record 37 of Set 3 | taoudenni
# Processing Record 38 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | kushima
# Processing Record 41 of Set 3 | pisco
# Processing Record 42 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 3 | sola
# Processing Record 44 of Set 3 | macusani
# Processing Record 45 of Set 3 | togur
# Processing Record 46 of Set 3 | mahajanga
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | qui nhon
# Processing Record 49 of Set 3 | ciudad bolivar
# Processing Record 50 of Set 3 | machali
# Processing Record 1 of Set 4 | stokmarknes
# Processing Record 2 of Set 4 | kochubey
# Processing Record 3 of Set 4 | santa cruz
# Processing Record 4 of Set 4 | maryville
# Processing Record 5 of Set 4 | port augusta
# Processing Record 6 of Set 4 | lashio
# Processing Record 7 of Set 4 | lethem
# Processing Record 8 of Set 4 | deputatskiy
# Processing Record 9 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 4 | vestmannaeyjar
# Processing Record 11 of Set 4 | rio gallegos
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | hovd
# Processing Record 15 of Set 4 | penzance
# Processing Record 16 of Set 4 | krutinka
# Processing Record 17 of Set 4 | santiago
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | isangel
# Processing Record 20 of Set 4 | jalalpur pirwala
# Processing Record 21 of Set 4 | saint anthony
# Processing Record 22 of Set 4 | zhigansk
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | maceio
# Processing Record 25 of Set 4 | the valley
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | santiago del estero
# Processing Record 28 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 4 | parati
# Processing Record 30 of Set 4 | vangaindrano
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | zapolyarnyy
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | bow island
# Processing Record 35 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 4 | guerrero negro
# Processing Record 37 of Set 4 | katobu
# Processing Record 38 of Set 4 | puerto baquerizo moreno
# Processing Record 39 of Set 4 | mehamn
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | bisceglie
# Processing Record 42 of Set 4 | tchamba
# Processing Record 43 of Set 4 | tome
# Processing Record 44 of Set 4 | klaksvik
# Processing Record 45 of Set 4 | yining
# Processing Record 46 of Set 4 | manavalakurichi
# Processing Record 47 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | hithadhoo
# Processing Record 1 of Set 5 | flinders
# Processing Record 2 of Set 5 | tabas
# Processing Record 3 of Set 5 | kuvandyk
# Processing Record 4 of Set 5 | russell
# Processing Record 5 of Set 5 | bahia honda
# Processing Record 6 of Set 5 | gornyy
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | kijang
# Processing Record 9 of Set 5 | asyut
# Processing Record 10 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 11 of Set 5 | broken hill
# Processing Record 12 of Set 5 | suao
# City not found. Skipping...
# Processing Record 13 of Set 5 | vao
# Processing Record 14 of Set 5 | buin
# Processing Record 15 of Set 5 | hamilton
# Processing Record 16 of Set 5 | grindavik
# Processing Record 17 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 5 | port-gentil
# Processing Record 19 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 5 | da nang
# Processing Record 21 of Set 5 | tasiilaq
# Processing Record 22 of Set 5 | lucapa
# Processing Record 23 of Set 5 | ilhabela
# Processing Record 24 of Set 5 | port hawkesbury
# Processing Record 25 of Set 5 | grand-lahou
# Processing Record 26 of Set 5 | malinovskiy
# Processing Record 27 of Set 5 | caravelas
# Processing Record 28 of Set 5 | karratha
# Processing Record 29 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 5 | codrington
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | visby
# Processing Record 33 of Set 5 | zlynka
# Processing Record 34 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 5 | hualmay
# Processing Record 36 of Set 5 | ketchikan
# Processing Record 37 of Set 5 | kodiak
# Processing Record 38 of Set 5 | vavoua
# Processing Record 39 of Set 5 | half moon bay
# Processing Record 40 of Set 5 | pevek
# Processing Record 41 of Set 5 | georgetown
# Processing Record 42 of Set 5 | rocha
# Processing Record 43 of Set 5 | sao jose da coroa grande
# Processing Record 44 of Set 5 | kaitangata
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | makungu
# Processing Record 49 of Set 5 | terney
# Processing Record 50 of Set 5 | hambantota
# Processing Record 1 of Set 6 | san marcos
# Processing Record 2 of Set 6 | lasa
# Processing Record 3 of Set 6 | coahuayana
# Processing Record 4 of Set 6 | calabozo
# Processing Record 5 of Set 6 | rio tercero
# Processing Record 6 of Set 6 | ancud
# Processing Record 7 of Set 6 | malakal
# Processing Record 8 of Set 6 | road town
# Processing Record 9 of Set 6 | tual
# Processing Record 10 of Set 6 | yar-sale
# Processing Record 11 of Set 6 | san patricio
# Processing Record 12 of Set 6 | ndende
# Processing Record 13 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 6 | sokoto
# Processing Record 15 of Set 6 | tiksi
# Processing Record 16 of Set 6 | bon accord
# Processing Record 17 of Set 6 | jishu
# Processing Record 18 of Set 6 | lumphat
# Processing Record 19 of Set 6 | bengkulu
# Processing Record 20 of Set 6 | nizhniy ingash
# Processing Record 21 of Set 6 | sokolo
# Processing Record 22 of Set 6 | puerto madryn
# Processing Record 23 of Set 6 | denia
# Processing Record 24 of Set 6 | naze
# Processing Record 25 of Set 6 | chulumani
# Processing Record 26 of Set 6 | zaltbommel
# Processing Record 27 of Set 6 | araouane
# Processing Record 28 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 29 of Set 6 | naples
# Processing Record 30 of Set 6 | celestun
# Processing Record 31 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | loningen
# Processing Record 33 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 6 | cascais
# Processing Record 35 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 6 | olpad
# Processing Record 37 of Set 6 | sao gabriel da cachoeira
# Processing Record 38 of Set 6 | stavern
# Processing Record 39 of Set 6 | dennery
# Processing Record 40 of Set 6 | gondar
# Processing Record 41 of Set 6 | suslovo
# Processing Record 42 of Set 6 | port lincoln
# Processing Record 43 of Set 6 | victor harbor
# Processing Record 44 of Set 6 | lebu
# Processing Record 45 of Set 6 | manakara
# Processing Record 46 of Set 6 | san cristobal
# Processing Record 47 of Set 6 | ostrovnoy
# Processing Record 48 of Set 6 | ottawa
# Processing Record 49 of Set 6 | nhulunbuy
# Processing Record 50 of Set 6 | chuy
# Processing Record 1 of Set 7 | pilot butte
# Processing Record 2 of Set 7 | sakaiminato
# Processing Record 3 of Set 7 | la ronge
# Processing Record 4 of Set 7 | aykhal
# Processing Record 5 of Set 7 | polis
# Processing Record 6 of Set 7 | juneau
# Processing Record 7 of Set 7 | nikolskoye
# Processing Record 8 of Set 7 | joao pinheiro
# Processing Record 9 of Set 7 | cayenne
# Processing Record 10 of Set 7 | baoqing
# Processing Record 11 of Set 7 | bandarbeyla
# Processing Record 12 of Set 7 | asau
# Processing Record 13 of Set 7 | rypefjord
# Processing Record 14 of Set 7 | minab
# Processing Record 15 of Set 7 | kavaratti
# Processing Record 16 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 7 | dandong
# Processing Record 18 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 7 | ust-kan
# Processing Record 20 of Set 7 | khandyga
# Processing Record 21 of Set 7 | alta floresta
# Processing Record 22 of Set 7 | piranhas
# Processing Record 23 of Set 7 | shuyskoye
# Processing Record 24 of Set 7 | harur
# Processing Record 25 of Set 7 | graaff-reinet
# Processing Record 26 of Set 7 | mabay
# Processing Record 27 of Set 7 | siedlce
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | sao filipe
# Processing Record 30 of Set 7 | constitucion
# Processing Record 31 of Set 7 | ahipara
# Processing Record 32 of Set 7 | uralskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | sitka
# Processing Record 34 of Set 7 | ambilobe
# Processing Record 35 of Set 7 | korla
# Processing Record 36 of Set 7 | tukrah
# Processing Record 37 of Set 7 | bereda
# Processing Record 38 of Set 7 | seoul
# Processing Record 39 of Set 7 | arawa
# Processing Record 40 of Set 7 | sukumo
# Processing Record 41 of Set 7 | vallenar
# Processing Record 42 of Set 7 | fortuna
# Processing Record 43 of Set 7 | port hardy
# Processing Record 44 of Set 7 | zlotoryja
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | ballina
# Processing Record 48 of Set 7 | batagay-alyta
# Processing Record 49 of Set 7 | lazurne
# Processing Record 50 of Set 7 | vila velha
# Processing Record 1 of Set 8 | tecoanapa
# Processing Record 2 of Set 8 | haines junction
# Processing Record 3 of Set 8 | tigil
# Processing Record 4 of Set 8 | szentgotthard
# Processing Record 5 of Set 8 | ritchie
# Processing Record 6 of Set 8 | jalu
# Processing Record 7 of Set 8 | dunedin
# Processing Record 8 of Set 8 | mendi
# Processing Record 9 of Set 8 | marquette
# Processing Record 10 of Set 8 | ndjole
# Processing Record 11 of Set 8 | leesburg
# Processing Record 12 of Set 8 | puerto padre
# Processing Record 13 of Set 8 | ereymentau
# Processing Record 14 of Set 8 | ibra
# Processing Record 15 of Set 8 | trzebiatow
# Processing Record 16 of Set 8 | fort nelson
# Processing Record 17 of Set 8 | ivolginsk
# Processing Record 18 of Set 8 | chiredzi
# Processing Record 19 of Set 8 | sao joao da barra
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | kalmunai
# Processing Record 22 of Set 8 | ilulissat
# Processing Record 23 of Set 8 | aklavik
# Processing Record 24 of Set 8 | praia
# Processing Record 25 of Set 8 | juntas
# Processing Record 26 of Set 8 | kyshtovka
# Processing Record 27 of Set 8 | geraldton
# Processing Record 28 of Set 8 | maumere
# Processing Record 29 of Set 8 | kandrian
# Processing Record 30 of Set 8 | cedral
# Processing Record 31 of Set 8 | innisfail
# Processing Record 32 of Set 8 | sorland
# Processing Record 33 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 8 | kentau
# Processing Record 35 of Set 8 | kikwit
# Processing Record 36 of Set 8 | rio grande
# Processing Record 37 of Set 8 | bonthe
# Processing Record 38 of Set 8 | mercedes
# Processing Record 39 of Set 8 | raudeberg
# Processing Record 40 of Set 8 | nova aurora
# Processing Record 41 of Set 8 | tezu
# Processing Record 42 of Set 8 | hirara
# Processing Record 43 of Set 8 | magadan
# Processing Record 44 of Set 8 | sabha
# Processing Record 45 of Set 8 | waipawa
# Processing Record 46 of Set 8 | mangaratiba
# Processing Record 47 of Set 8 | chor
# Processing Record 48 of Set 8 | omsukchan
# Processing Record 49 of Set 8 | kununurra
# Processing Record 50 of Set 8 | saint-paul
# Processing Record 1 of Set 9 | anantapur
# Processing Record 2 of Set 9 | nemuro
# Processing Record 3 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 9 | baykit
# Processing Record 5 of Set 9 | lincoln
# Processing Record 6 of Set 9 | beringovskiy
# Processing Record 7 of Set 9 | margate
# Processing Record 8 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 9 | gamba
# Processing Record 10 of Set 9 | roebourne
# Processing Record 11 of Set 9 | tokur
# Processing Record 12 of Set 9 | praia da vitoria
# Processing Record 13 of Set 9 | kruisfontein
# Processing Record 14 of Set 9 | ketrzyn
# Processing Record 15 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 9 | nandu
# Processing Record 17 of Set 9 | vila franca do campo
# Processing Record 18 of Set 9 | parana
# Processing Record 19 of Set 9 | banda aceh
# Processing Record 20 of Set 9 | richards bay
# Processing Record 21 of Set 9 | marienburg
# Processing Record 22 of Set 9 | aranda de duero
# Processing Record 23 of Set 9 | kaset sombun
# Processing Record 24 of Set 9 | eyl
# Processing Record 25 of Set 9 | batemans bay
# Processing Record 26 of Set 9 | hay river
# Processing Record 27 of Set 9 | presidencia roque saenz pena
# Processing Record 28 of Set 9 | vilhena
# Processing Record 29 of Set 9 | chililabombwe
# Processing Record 30 of Set 9 | vrontados
# Processing Record 31 of Set 9 | grand forks
# Processing Record 32 of Set 9 | fare
# Processing Record 33 of Set 9 | merauke
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | beitbridge
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | cah ab
# City not found. Skipping...
# Processing Record 38 of Set 9 | mayo
# Processing Record 39 of Set 9 | kieta
# Processing Record 40 of Set 9 | antofagasta
# Processing Record 41 of Set 9 | kosa
# Processing Record 42 of Set 9 | shitanjing
# Processing Record 43 of Set 9 | calvinia
# Processing Record 44 of Set 9 | erenhot
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | bafia
# Processing Record 47 of Set 9 | oksfjord
# Processing Record 48 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 49 of Set 9 | west bay
# Processing Record 50 of Set 9 | chik
# Processing Record 1 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 10 | muhos
# Processing Record 3 of Set 10 | barretos
# Processing Record 4 of Set 10 | kerchevskiy
# Processing Record 5 of Set 10 | traralgon
# Processing Record 6 of Set 10 | paita
# Processing Record 7 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 8 of Set 10 | shambu
# Processing Record 9 of Set 10 | mongo
# Processing Record 10 of Set 10 | komagane
# Processing Record 11 of Set 10 | tabou
# Processing Record 12 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 10 | george town
# Processing Record 14 of Set 10 | isiro
# Processing Record 15 of Set 10 | palmas
# Processing Record 16 of Set 10 | mount isa
# Processing Record 17 of Set 10 | sept-iles
# Processing Record 18 of Set 10 | iralaya
# Processing Record 19 of Set 10 | volkhov
# Processing Record 20 of Set 10 | saldanha
# Processing Record 21 of Set 10 | toora-khem
# Processing Record 22 of Set 10 | naliya
# Processing Record 23 of Set 10 | brae
# Processing Record 24 of Set 10 | basoko
# Processing Record 25 of Set 10 | lugovoy
# Processing Record 26 of Set 10 | quelimane
# Processing Record 27 of Set 10 | along
# Processing Record 28 of Set 10 | imeni babushkina
# Processing Record 29 of Set 10 | san juan
# Processing Record 30 of Set 10 | faanui
# Processing Record 31 of Set 10 | karmana
# City not found. Skipping...
# Processing Record 32 of Set 10 | barraute
# Processing Record 33 of Set 10 | yashkul
# Processing Record 34 of Set 10 | olavarria
# Processing Record 35 of Set 10 | general roca
# Processing Record 36 of Set 10 | robertsport
# Processing Record 37 of Set 10 | kharan
# Processing Record 38 of Set 10 | kiruna
# Processing Record 39 of Set 10 | zhezkazgan
# Processing Record 40 of Set 10 | naranjal
# Processing Record 41 of Set 10 | quatre cocos
# Processing Record 42 of Set 10 | kavieng
# Processing Record 43 of Set 10 | xuddur
# Processing Record 44 of Set 10 | elat
# Processing Record 45 of Set 10 | ngunguru
# Processing Record 46 of Set 10 | oktyabrskoye
# Processing Record 47 of Set 10 | miri
# Processing Record 48 of Set 10 | pangnirtung
# Processing Record 49 of Set 10 | cidreira
# Processing Record 50 of Set 10 | sao mateus do maranhao
# Processing Record 1 of Set 11 | poltavka
# Processing Record 2 of Set 11 | upernavik
# Processing Record 3 of Set 11 | shangrao
# Processing Record 4 of Set 11 | portland
# Processing Record 5 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 11 | bocas del toro
# Processing Record 8 of Set 11 | payson
# Processing Record 9 of Set 11 | portobelo
# Processing Record 10 of Set 11 | at-bashi
# Processing Record 11 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 11 | salinopolis
# Processing Record 13 of Set 11 | gobabis
# Processing Record 14 of Set 11 | karpogory
# Processing Record 15 of Set 11 | anchorage
# Processing Record 16 of Set 11 | kiunga
# Processing Record 17 of Set 11 | yulara
# Processing Record 18 of Set 11 | abnub
# Processing Record 19 of Set 11 | honningsvag
# Processing Record 20 of Set 11 | krasnoarmeysk
# Processing Record 21 of Set 11 | okmulgee
# Processing Record 22 of Set 11 | najran
# Processing Record 23 of Set 11 | lafiagi
# Processing Record 24 of Set 11 | hami
# Processing Record 25 of Set 11 | calvia
# Processing Record 26 of Set 11 | samarai
# Processing Record 27 of Set 11 | waynesville
# Processing Record 28 of Set 11 | saint-pierre
# Processing Record 29 of Set 11 | san ramon
# Processing Record 30 of Set 11 | anadyr
# Processing Record 31 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 11 | misratah
# Processing Record 33 of Set 11 | kashi
# Processing Record 34 of Set 11 | miyako
# Processing Record 35 of Set 11 | dingle
# Processing Record 36 of Set 11 | verkhoyansk
# Processing Record 37 of Set 11 | axim
# Processing Record 38 of Set 11 | mareeba
# Processing Record 39 of Set 11 | alice springs
# Processing Record 40 of Set 11 | kaeo
# Processing Record 41 of Set 11 | bosaso
# Processing Record 42 of Set 11 | laukaa
# Processing Record 43 of Set 11 | yarada
# Processing Record 44 of Set 11 | pandamatenga
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | arona
# Processing Record 47 of Set 11 | novyy urengoy
# Processing Record 48 of Set 11 | lata
# Processing Record 49 of Set 11 | mangrol
# Processing Record 50 of Set 11 | wilmington
# Processing Record 1 of Set 12 | souillac
# Processing Record 2 of Set 12 | ulaanbaatar
# Processing Record 3 of Set 12 | birobidzhan
# Processing Record 4 of Set 12 | kudahuvadhoo
# Processing Record 5 of Set 12 | suifenhe
# Processing Record 6 of Set 12 | gat
# Processing Record 7 of Set 12 | tanjong tokong
# City not found. Skipping...
# Processing Record 8 of Set 12 | zunyi
# Processing Record 9 of Set 12 | camana
# Processing Record 10 of Set 12 | mao
# Processing Record 11 of Set 12 | cairo
# Processing Record 12 of Set 12 | christchurch
# Processing Record 13 of Set 12 | eureka
# Processing Record 14 of Set 12 | chanthaburi
# Processing Record 15 of Set 12 | ugoofaaru
# Processing Record 16 of Set 12 | balogo
# Processing Record 17 of Set 12 | mbarara
# Processing Record 18 of Set 12 | awbari
# Processing Record 19 of Set 12 | okhotsk
# Processing Record 20 of Set 12 | petrokamenskoye
# Processing Record 21 of Set 12 | cururupu
# Processing Record 22 of Set 12 | paamiut
# Processing Record 23 of Set 12 | whitefish
# Processing Record 24 of Set 12 | chicama
# Processing Record 25 of Set 12 | bantry
# Processing Record 26 of Set 12 | mahebourg
# Processing Record 27 of Set 12 | luderitz
# Processing Record 28 of Set 12 | nuuk
# Processing Record 29 of Set 12 | harlingen
# Processing Record 30 of Set 12 | marystown
# Processing Record 31 of Set 12 | nelson bay
# Processing Record 32 of Set 12 | mazyr
# Processing Record 33 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 12 | campoverde
# Processing Record 35 of Set 12 | port blair
# Processing Record 36 of Set 12 | linxia
# Processing Record 37 of Set 12 | chumikan
# Processing Record 38 of Set 12 | smithers
# Processing Record 39 of Set 12 | hidalgo
# Processing Record 40 of Set 12 | havre-saint-pierre
# Processing Record 41 of Set 12 | garissa
# Processing Record 42 of Set 12 | hobyo
# Processing Record 43 of Set 12 | loukhi
# Processing Record 44 of Set 12 | ormara
# Processing Record 45 of Set 12 | port hedland
# Processing Record 46 of Set 12 | mamallapuram
# Processing Record 47 of Set 12 | kilindoni
# Processing Record 48 of Set 12 | fukue
# Processing Record 49 of Set 12 | aksarka
# Processing Record 50 of Set 12 | haradok
# Processing Record 1 of Set 13 | ridgecrest
# Processing Record 2 of Set 13 | teahupoo
# Processing Record 3 of Set 13 | azare
# Processing Record 4 of Set 13 | batagay
# Processing Record 5 of Set 13 | quang ngai
# Processing Record 6 of Set 13 | chengam
# Processing Record 7 of Set 13 | san quintin
# Processing Record 8 of Set 13 | meadow lake
# Processing Record 9 of Set 13 | sawakin
# Processing Record 10 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 13 | bambous virieux
# Processing Record 12 of Set 13 | sibolga
# Processing Record 13 of Set 13 | barcelona
# Processing Record 14 of Set 13 | san andres
# Processing Record 15 of Set 13 | roros
# Processing Record 16 of Set 13 | yuanping
# Processing Record 17 of Set 13 | tarakan
# Processing Record 18 of Set 13 | lagunas
# Processing Record 19 of Set 13 | laguna
# Processing Record 20 of Set 13 | tessalit
# Processing Record 21 of Set 13 | griffith
# Processing Record 22 of Set 13 | vardo
# Processing Record 23 of Set 13 | deep river
# Processing Record 24 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 13 | nichlaul
# Processing Record 26 of Set 13 | makakilo city
# Processing Record 27 of Set 13 | hun
# Processing Record 28 of Set 13 | waddan
# Processing Record 29 of Set 13 | shenzhen
# Processing Record 30 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 13 | buraydah
# Processing Record 32 of Set 13 | nouadhibou
# Processing Record 33 of Set 13 | vega de alatorre
# Processing Record 34 of Set 13 | muros
# Processing Record 35 of Set 13 | puerto gaitan
# Processing Record 36 of Set 13 | kloulklubed
# Processing Record 37 of Set 13 | mitsamiouli
# Processing Record 38 of Set 13 | koslan
# Processing Record 39 of Set 13 | pedernales
# Processing Record 40 of Set 13 | artyom
# Processing Record 41 of Set 13 | tsaratanana
# Processing Record 42 of Set 13 | murindo
# Processing Record 43 of Set 13 | cukai
# Processing Record 44 of Set 13 | rustenburg
# Processing Record 45 of Set 13 | port macquarie
# Processing Record 46 of Set 13 | baley
# Processing Record 47 of Set 13 | sao francisco
# Processing Record 48 of Set 13 | coruripe
# Processing Record 49 of Set 13 | acapulco
# Processing Record 50 of Set 13 | acajutla
# Processing Record 1 of Set 14 | sakakah
# Processing Record 2 of Set 14 | troitskoye
# Processing Record 3 of Set 14 | churapcha
# Processing Record 4 of Set 14 | abeche
# Processing Record 5 of Set 14 | syracuse
# Processing Record 6 of Set 14 | barth
# Processing Record 7 of Set 14 | bathsheba
# Processing Record 8 of Set 14 | akyab
# Processing Record 9 of Set 14 | pandan
# Processing Record 10 of Set 14 | sinegorye
# Processing Record 11 of Set 14 | guantanamo
# Processing Record 12 of Set 14 | teluk nibung
# Processing Record 13 of Set 14 | nsanje
# Processing Record 14 of Set 14 | zernograd
# Processing Record 15 of Set 14 | podbelsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | jeremie
# Processing Record 17 of Set 14 | malino
# Processing Record 18 of Set 14 | okha
# Processing Record 19 of Set 14 | henties bay
# Processing Record 20 of Set 14 | yaan
# Processing Record 21 of Set 14 | barranca
# Processing Record 22 of Set 14 | honiara
# Processing Record 23 of Set 14 | cochrane
# Processing Record 24 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 14 | grand gaube
# Processing Record 26 of Set 14 | matara
# Processing Record 27 of Set 14 | aloleng
# Processing Record 28 of Set 14 | aulnoye-aymeries
# Processing Record 29 of Set 14 | balaguer
# Processing Record 30 of Set 14 | ohara
# Processing Record 31 of Set 14 | ratnagiri
# Processing Record 32 of Set 14 | forio
# Processing Record 33 of Set 14 | khromtau
# Processing Record 34 of Set 14 | gainesville
# Processing Record 35 of Set 14 | jahrom
# City not found. Skipping...
# Processing Record 36 of Set 14 | zwedru
# Processing Record 37 of Set 14 | taveta
# Processing Record 38 of Set 14 | imeni poliny osipenko
# Processing Record 39 of Set 14 | kirkkonummi
# Processing Record 40 of Set 14 | zhireken
# Processing Record 41 of Set 14 | sergeyevka
# Processing Record 42 of Set 14 | catamarca
# Processing Record 43 of Set 14 | butia
# Processing Record 44 of Set 14 | muzaffarabad
# Processing Record 45 of Set 14 | longhua
# Processing Record 46 of Set 14 | berlevag
# Processing Record 47 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 14 | pauini
# Processing Record 49 of Set 14 | ust-tsilma
# Processing Record 50 of Set 14 | barra do garcas
# Processing Record 1 of Set 15 | da lat
# Processing Record 2 of Set 15 | wuwei
# Processing Record 3 of Set 15 | bud
# Processing Record 4 of Set 15 | santa marinella
# Processing Record 5 of Set 15 | jasper
# Processing Record 6 of Set 15 | hermiston
# Processing Record 7 of Set 15 | nuevo progreso
# Processing Record 8 of Set 15 | narsaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21592\3028701525.py in <module>
#       1 # Convert the array of dictionaries to a Pandas DataFrame.
# ----> 2 city_data_df = pd.DataFrame(city_data)
#       3 city_data_df.head(10)
#
# NameError: name 'city_data' is not defined

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index="City_ID")
